# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('y_probs_config1.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
data = pd.read_csv('y_probs_config2.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
data = pd.read_csv('y_probs_config3.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
data = pd.read_csv('y_probs_config4.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
data = pd.read_csv('y_probs_config5.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
data = pd.read_csv('y_probs_config6.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
data = pd.read_csv('y_probs_config7.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
plt.plot(data[2].diff(periods=100))
#plot the change in data[2]
print(data[2].diff(periods=100).mean())
# Out:
# 0.006211887383140808

# %%
data = pd.read_csv('y_probs_config8.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
data = pd.read_csv('y_probs_config9.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
plt.plot(data[:2500][0])

# %%
data = pd.read_csv('y_probs.csv', header=None)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 4))
ax1.plot(data[0])
ax1.plot(data[2], alpha=0.5)
ax2.plot(data[3])

# %%
plt.plot(data[0])
